# %%
import pandas as pd
from pathlib import Path
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import numpy as np

# %%
#Child age range 0-10, Teen age range 11-17
#All data reflected is killed by gun incident
child = pd.read_csv('children.csv')
teen = pd.read_csv('teen.csv')

# %%
child.rename(columns={'# Killed': 'children-killed', '# Injured': 'children-injured'}, inplace=True)
teen.rename(columns={'# Killed': 'teen-killed', '# Injured': 'teen-injured'}, inplace=True)

# %%
child.drop(['Incident ID', 'Incident Date','City Or County','Operations','Address'], axis = 1, inplace = True) 
teen.drop(['Incident ID', 'Incident Date','City Or County','Operations','Address'], axis = 1, inplace = True)

# %%
grp_child = child.groupby(['State'])['children-killed','children-injured'].sum()
grp_teen = teen.groupby(['State'])['teen-killed','teen-injured'].sum()
# Out:
# C:\Users\tinph\AppData\Local\Temp\ipykernel_11048\4011172287.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grp_child = child.groupby(['State'])['children-killed','children-injured'].sum()
# C:\Users\tinph\AppData\Local\Temp\ipykernel_11048\4011172287.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grp_teen = teen.groupby(['State'])['teen-killed','teen-injured'].sum()

# %%
#Texas has highest incidents 
df = pd.concat([grp_child, grp_teen],axis=1)
df
# Out:
#                       children-killed  children-injured  teen-killed  \
# State
# Alabama                          76.0              13.0         72.0
# Alaska                           31.0               0.0          9.0
# Arizona                          73.0              12.0         52.0
# Arkansas                         57.0               5.0         31.0
# California                      159.0              47.0        148.0
# Colorado                         51.0               0.0         48.0
# Connecticut                      32.0               2.0         14.0
# Delaware                          5.0               0.0          4.0
# District of Columbia              7.0               9.0         21.0
# Florida                         202.0              37.0        130.0
# Georgia                         137.0              16.0        131.0
# Hawaii                            6.0               0.0          NaN
# Idaho                            12.0               0.0          NaN
# Illinois                        109.0              21.0        144.0
# Indiana                          78.0               9.0         61.0
# Iowa                             19.0               0.0          6.0
# Kansas                           27.0               7.0         33.0
# Kentucky                         66.0               6.0         29.0
# Louisiana                       114.0              21.0         96.0
# Maine                            11.0               2.0          1.0
# Maryland                         50.0               5.0         54.0
# Massachusetts                     9.0               0.0          8.0
# Michigan                        115.0              19.0         64.0
# Minnesota                        41.0               3.0         23.0
# Mississippi                      69.0              17.0         51.0
# Missouri                        150.0              25.0         63.0
# Montana                          27.0               2.0          5.0
# Nebraska                          7.0               3.0          8.0
# Nevada                           32.0               1.0         15.0
# New Hampshire                     7.0               0.0          2.0
# New Jersey                       34.0               5.0         27.0
# New Mexico                       30.0               1.0         24.0
# New York                         39.0              13.0         54.0
# North Carolina                  117.0              27.0        121.0
# North Dakota                      6.0               0.0          1.0
# Ohio                            148.0              36.0        106.0
# Oklahoma                         81.0               5.0         36.0
# Oregon                           37.0               2.0         10.0
# Pennsylvania                    108.0              15.0        110.0
# South Carolina                  126.0              21.0         71.0
# South Dakota                     13.0               0.0          1.0
# Tennessee                       105.0              18.0         59.0
# Texas                           375.0              71.0        271.0
# Utah                             42.0               3.0         13.0
# Vermont                           2.0               0.0          1.0
# Virginia                         89.0              13.0         70.0
# Washington                       38.0               3.0         17.0
# West Virginia                    24.0               4.0          7.0
# Wisconsin                        56.0               5.0         54.0
# Wyoming                           2.0               0.0          1.0
# Rhode Island                      NaN               NaN          2.0
#
#                       teen-injured
# State
# Alabama                       19.0
# Alaska                         0.0
# Arizona                       18.0
# Arkansas                       2.0
# California                    41.0
# Colorado                      22.0
# Connecticut                    1.0
# Delaware                       3.0
# District of Columbia           7.0
# Florida                       33.0
# Georgia                       44.0
# Hawaii                         NaN
# Idaho                          NaN
# Illinois                      52.0
# Indiana                       15.0
# Iowa                           2.0
# Kansas                        11.0
# Kentucky                       9.0
# Louisiana                     23.0
# Maine                          0.0
# Maryland                      20.0
# Massachusetts                  3.0
# Michigan                      22.0
# Minnesota                      5.0
# Mississippi                   13.0
# Missouri                      15.0
# Montana                        1.0
# Nebraska                       0.0
# Nevada                         3.0
# New Hampshire                  0.0
# New Jersey                    13.0
# New Mexico                     7.0
# New York                      14.0
# North Carolina                38.0
# North Dakota                   0.0
# Ohio                          29.0
# Oklahoma                       9.0
# Oregon                         6.0
# Pennsylvania                  40.0
# South Carolina                17.0
# South Dakota                   0.0
# Tennessee                     20.0
# Texas                         43.0
# Utah                           4.0
# Vermont                        0.0
# Virginia                      22.0
# Washington                     5.0
# West Virginia                  2.0
# Wisconsin                     12.0
# Wyoming                        0.0
# Rhode Island                   0.0

# %%
#Years: 2014 - Dec 2022, updates on a weekly basis. 
df.replace(np.nan, 0, inplace = True)
df.sort_values(by=['children-killed'], ascending=False)
# Out:
#                       children-killed  children-injured  teen-killed  \
# State
# Texas                           375.0              71.0        271.0
# Florida                         202.0              37.0        130.0
# California                      159.0              47.0        148.0
# Missouri                        150.0              25.0         63.0
# Ohio                            148.0              36.0        106.0
# Georgia                         137.0              16.0        131.0
# South Carolina                  126.0              21.0         71.0
# North Carolina                  117.0              27.0        121.0
# Michigan                        115.0              19.0         64.0
# Louisiana                       114.0              21.0         96.0
# Illinois                        109.0              21.0        144.0
# Pennsylvania                    108.0              15.0        110.0
# Tennessee                       105.0              18.0         59.0
# Virginia                         89.0              13.0         70.0
# Oklahoma                         81.0               5.0         36.0
# Indiana                          78.0               9.0         61.0
# Alabama                          76.0              13.0         72.0
# Arizona                          73.0              12.0         52.0
# Mississippi                      69.0              17.0         51.0
# Kentucky                         66.0               6.0         29.0
# Arkansas                         57.0               5.0         31.0
# Wisconsin                        56.0               5.0         54.0
# Colorado                         51.0               0.0         48.0
# Maryland                         50.0               5.0         54.0
# Utah                             42.0               3.0         13.0
# Minnesota                        41.0               3.0         23.0
# New York                         39.0              13.0         54.0
# Washington                       38.0               3.0         17.0
# Oregon                           37.0               2.0         10.0
# New Jersey                       34.0               5.0         27.0
# Nevada                           32.0               1.0         15.0
# Connecticut                      32.0               2.0         14.0
# Alaska                           31.0               0.0          9.0
# New Mexico                       30.0               1.0         24.0
# Kansas                           27.0               7.0         33.0
# Montana                          27.0               2.0          5.0
# West Virginia                    24.0               4.0          7.0
# Iowa                             19.0               0.0          6.0
# South Dakota                     13.0               0.0          1.0
# Idaho                            12.0               0.0          0.0
# Maine                            11.0               2.0          1.0
# Massachusetts                     9.0               0.0          8.0
# New Hampshire                     7.0               0.0          2.0
# Nebraska                          7.0               3.0          8.0
# District of Columbia              7.0               9.0         21.0
# North Dakota                      6.0               0.0          1.0
# Hawaii                            6.0               0.0          0.0
# Delaware                          5.0               0.0          4.0
# Vermont                           2.0               0.0          1.0
# Wyoming                           2.0               0.0          1.0
# Rhode Island                      0.0               0.0          2.0
#
#                       teen-injured
# State
# Texas                         43.0
# Florida                       33.0
# California                    41.0
# Missouri                      15.0
# Ohio                          29.0
# Georgia                       44.0
# South Carolina                17.0
# North Carolina                38.0
# Michigan                      22.0
# Louisiana                     23.0
# Illinois                      52.0
# Pennsylvania                  40.0
# Tennessee                     20.0
# Virginia                      22.0
# Oklahoma                       9.0
# Indiana                       15.0
# Alabama                       19.0
# Arizona                       18.0
# Mississippi                   13.0
# Kentucky                       9.0
# Arkansas                       2.0
# Wisconsin                     12.0
# Colorado                      22.0
# Maryland                      20.0
# Utah                           4.0
# Minnesota                      5.0
# New York                      14.0
# Washington                     5.0
# Oregon                         6.0
# New Jersey                    13.0
# Nevada                         3.0
# Connecticut                    1.0
# Alaska                         0.0
# New Mexico                     7.0
# Kansas                        11.0
# Montana                        1.0
# West Virginia                  2.0
# Iowa                           2.0
# South Dakota                   0.0
# Idaho                          0.0
# Maine                          0.0
# Massachusetts                  3.0
# New Hampshire                  0.0
# Nebraska                       0.0
# District of Columbia           7.0
# North Dakota                   0.0
# Hawaii                         0.0
# Delaware                       3.0
# Vermont                        0.0
# Wyoming                        0.0
# Rhode Island                   0.0

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaled_data1 = scaler.fit_transform(df.iloc[: , 1:])

# %%
pca1 = PCA(n_components=2)
pca_transformed_data1 = pca1.fit_transform(scaled_data1)
pca1.explained_variance_ratio_.sum()
# Out:
# 0.9904618125129161

# %%
pca1.explained_variance_ratio_
# Out:
# array([0.91734073, 0.07312108])

# %%
# Transform PCA data to a DataFrame
df3 = pd.DataFrame(
    data=pca_transformed_data1, columns=["PC1", "PC2"]
)
df3.head()
# Out:
#         PC1       PC2
# 0  0.642605 -0.162390
# 1 -1.380301  0.139801
# 2  0.333605 -0.165551
# 3 -0.843697  0.294960
# 4  3.797236  0.449082

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(df3)
    inertia.append(km.inertia_)

# Creating the Elbow Curve
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)

plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(list(range(11)))
plt.title('Elbow Curve')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
# Out:
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
model = KMeans(n_clusters=4, random_state=0)

# Fit the model
model.fit(df3)

# Predict clusters
predictions = model.predict(df3)

# Add the predicted class column to the dataframe
df3["class"] = model.labels_
df3.head()
# Out:
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
#         PC1       PC2  class
# 0  0.642605 -0.162390      2
# 1 -1.380301  0.139801      0
# 2  0.333605 -0.165551      2
# 3 -0.843697  0.294960      0
# 4  3.797236  0.449082      1

# %%
plt.scatter(x=df3['PC1'], y=df3['PC2'], c=df3['class'])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('#killed & #injured clusters')
plt.show()

# %%
from sklearn.metrics import silhouette_score
sil_avg = []
range_n_clusters = [2, 3, 4, 5, 6, 7, 8, 9, 10]
for s in range_n_clusters:
 kmeans = KMeans(n_clusters = s).fit(df3)
 labels = kmeans.labels_
 sil_avg.append(silhouette_score(df3, labels, metric = 'euclidean'))
# Out:
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\tinph\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.plot(range_n_clusters,sil_avg,'bx-')
plt.xlabel('Values of K')
plt.ylabel('Silhouette score')
plt.title('Silhouette analysis For Optimal k')
plt.show()

# %% [markdown]
# Using the above Silhouette analysis, we can choose K’s optimal value as 4 because the average silhouette score is higher and indicates that the data points are optimally positioned.
# So the number of group data we define are 4 include children/teen killed/injured
